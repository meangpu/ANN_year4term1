# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_openml
import time
from sklearn.model_selection import train_test_split

t1 = time.time()
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
t2 = time.time()
print('Loading time', t2-t1)

print(X.shape)  # object with shape 70000 * 784 pixel
print(y.shape)  # answer of x

X_train, X_test, Y_train, Y_test = train_test_split(X, y, stratify=y, test_size=0.14, random_state=21)
# Out:
# Loading time 18.044572591781616
# (70000, 784)
# (70000,)

# %%
Y_train = Y_train.astype(int)
Y_train
# print(y)
# print(y.shape)  # answer of x

# Y_int_array.reshape(Y_train.shape)
# print(Y_int_array)
# Out:
# array([6, 6, 3, ..., 7, 2, 1])

# %%
num_class = 10
seed = 6
f, ax = plt.subplots(10, num_class, figsize=(20, 20))

Y_int_array = Y_train.astype(int)

for k in range(0, num_class):
    for i in range(0, num_class):
        sample = (X_train[np.where(Y_int_array == i)[0][k],:].reshape((28,28)))
        ax[k, i].imshow(sample, cmap=plt.cm.bone)
        ax[k, i].set_title(f"number {i}")
