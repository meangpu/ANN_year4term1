# %%
import numpy as np
from ANN_feAux import * 
from matplotlib import pyplot as plt

dat = np.load('P1data.npy', allow_pickle=True) 
X = dat[:,:-1].astype(float) 
Y = dat[:, -1] 

print(X.shape) # (4000, 2)
print(Y.shape) # (4000,)
print(X[:5,:]) 
print(Y[:5])
# Out:
# (4000, 2)
# (4000,)
# [[ 8.65268529  4.71209526]
#  [-0.85567603  6.2998235 ]
#  [ 1.08697548  4.90480962]
#  [ 3.82413956  6.92769663]
#  [ 1.03674595  1.62243513]]
# ['D' 'D' 'A' 'B' 'A']

# %%
plt.plot(X[:, 0], X[:, 1], 'b.') 
plt.title('This is graph image of number')
# Out:
# Text(0.5, 1.0, 'This is graph image of number')

# %%
newDat = dat

# %%
a_list = []
b_list = []
c_list = []
d_list = []
for i in dat:
    if(i[2] == "A"):
        a_list.append(i)
    elif(i[2] == "B"):
        b_list.append(i)
    elif(i[2] == "C"):
        c_list.append(i)
    elif(i[2] == "D"):
        d_list.append(i)

a_arr = np.array(a_list)
b_arr = np.array(b_list)
c_arr = np.array(c_list)
d_arr = np.array(d_list)

# %%
plt.plot(a_arr[:, 0].astype(float) , a_arr[:, 1].astype(float), "r.") 
plt.plot(b_arr[:, 0].astype(float) , b_arr[:, 1].astype(float), "g.") 
plt.plot(c_arr[:, 0].astype(float) , c_arr[:, 1].astype(float), "b.") 
plt.plot(d_arr[:, 0].astype(float) , d_arr[:, 1].astype(float), "y.") 
plt.title('ABCD')

# plt.plot(X[:, 0], X[:, 1], 'b.') 
# plt.title('This is graph image of number')
# Out:
# Text(0.5, 1.0, 'ABCD')

# %%
d_arr
# Out:
# array([['8.65268528666238', '4.712095256752652', 'D'],
#        ['-0.8556760324340198', '6.299823504053325', 'D'],
#        ['9.118396089065394', '5.46984010856165', 'D'],
#        ...,
#        ['2.64230663723864', '6.303273063983036', 'D'],
#        ['4.009577120208015', '2.0196164319329117', 'D'],
#        ['4.895023863572728', '1.7194218916714252', 'D']], dtype='<U32')

# %%
print(np.unique(dat[:, -1]))
# Out:
# ['A' 'B' 'C' 'D']

# %%
import numpy as np
dummypar = np.load('P1_dummypar.npy', allow_pickle=True) 
dummyw = np.load('P1_dummyw.npy', allow_pickle=True).tolist()
meangpuW = np.load('P1_meang.npy', allow_pickle=True).tolist()

# %%
# print(dummypar)
print(dummyw['v'])
# c=1 v=8*1 b=1*8 w=8*2
# Out:
# [[-2.91749983  2.37518075  1.74496648  1.06511327 -2.86268197  2.53622347
#   -1.69350585 -1.98397879]]

# %%
print(meangpuW['v'])
# c=1*4 v=8*4 b=1*8 w = (8*2)
# Out:
# [[-0.96052094 -1.37570046  0.23357412  0.21896917]
#  [ 0.26000979  0.10250975 -0.06911432  0.2230267 ]
#  [-0.15903947 -0.37808748  0.02988637  0.34633107]
#  [-0.1348486   1.00200026 -1.24207421  0.34592785]]
